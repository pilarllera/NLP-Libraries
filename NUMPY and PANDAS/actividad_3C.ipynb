# %%
import pandas as pd

# %%
# Pregunta 1: Crea el siguiente DataFrame
import pandas as pd

# Crear un DataFrame con las columnas y datos deseados
tabla1 = pd.DataFrame({
    '': ["Febrero", "Julio"],
    'Pepe': ["No presentado", "Matrícula de honor"],
    'Pepa': ["Insuficiente", "Notable"]
})
# Mostrar el DataFrame
tabla1.style.hide_index()
# Out:
#                        Pepe          Pepa
# Febrero       No presentado  Insuficiente
# Julio    Matrícula de honor       Notable

# %%
# Pregunta 2: Crea la siguiente Series
import pandas as pd

# Crear un objeto Series

serie = pd.Series({
    'Media 2020': 6.0,
    'Media 2021': 5.0,
    'Media 2022': 7.8
}, name='Notas medias', dtype = float)

# Mostrar la Serie
print(serie)
# Out:
# Media 2020    6.0
# Media 2021    5.0
# Media 2022    7.8
# Name: Notas medias, dtype: float64

# %%
# Pregunta 3: Crea un DataFrame a partir del CSV IMDB Dataset SPANISH.csv disponible en el Campus Virtual (es un recorte del dataset disponibe en
# https://www.kaggle.com/datasets/luisdiegofv97/imdb-dataset-of-50k-movie-reviews-spanish?select=IMDB+Dataset+SPANISH.csv

# Debes descargarlo, subirlo al servidor de Colab y leerlo desde la ruta en la que lo sitúes
# Muestra por pantalla la cabecera de la tabla tal y como se muestra a continuación:

# Observa cómo los posibles errores se solucionan con estos parámetros:
# on_bad_lines='skip'
# engine='python'
# ¿Para qué sirven?
imdb = pd.read_csv("/content/IMDB Dataset SPANISH.csv", encoding='utf-8',on_bad_lines='skip', engine='python')
imdb.head(5)
# Out:
#    Unnamed: 0                                          review_en  \
# 0           0  One of the other reviewers has mentioned that ...
# 1           1  A wonderful little production. The filming tec...
# 2           2  I thought this was a wonderful way to spend ti...
# 3           3  Basically there's a family where a little boy ...
# 4           4  Petter Mattei's "Love in the Time of Money" is...
#
#                                            review_es sentiment sentimiento
# 0  Uno de los otros críticos ha mencionado que de...  positive    positivo
# 1  Una pequeña pequeña producción.La técnica de f...  positive    positivo
# 2  Pensé que esta era una manera maravillosa de p...  positive    positivo
# 3  Básicamente, hay una familia donde un niño peq...  negative    negativo
# 4  El "amor en el tiempo" de Petter Mattei es una...  positive    positivo

# %%
# Pregunta 4.1: Muestra por pantalla las últimas 10 reseñas del dataset
imdb.tail(10)
# Out:
#        Unnamed: 0                                          review_en  \
# 49990       49990  Lame, lame, lame!!! A 90-minute cringe-fest th...
# 49991       49991  Les Visiteurs, the first movie about the medie...
# 49992       49992  John Garfield plays a Marine who is blinded by...
# 49993       49993  Robert Colomb has two full-time jobs. He's kno...
# 49994       49994  This is your typical junk comedy.There are alm...
# 49995       49995  I thought this movie did a down right good job...
# 49996       49996  Bad plot, bad dialogue, bad acting, idiotic di...
# 49997       49997  I am a Catholic taught in parochial elementary...
# 49998       49998  I'm going to have to disagree with the previou...
# 49999       49999  No one expects the Star Trek movies to be high...
#
#                                                review_es sentiment sentimiento
# 49990  Cojo, cojo, cojo !!!Un festival de 90 minutos ...  negative    negativo
# ...

# %%
# Pregunta 5: Muestra solamente el texto en inglés de la segunda y la tercera reseña
imdb.loc[1:2,"review_en"]
# Out:
# 1    A wonderful little production. The filming tec...
# 2    I thought this was a wonderful way to spend ti...
# Name: review_en, dtype: object

# %%
# Pregunta 6: Muestra por pantalla solamente las reseñas en español y su clasificación de sentimiento
imdb[['review_es', 'sentimiento']]
# Out:
#                                                review_es sentimiento
# 0      Uno de los otros críticos ha mencionado que de...    positivo
# 1      Una pequeña pequeña producción.La técnica de f...    positivo
# 2      Pensé que esta era una manera maravillosa de p...    positivo
# 3      Básicamente, hay una familia donde un niño peq...    negativo
# 4      El "amor en el tiempo" de Petter Mattei es una...    positivo
# ...                                                  ...         ...
# 49995  Pensé que esta película hizo un buen trabajo a...    positivo
# 49996  Mala parcela, mal diálogo, mala actuación, dir...    negativo
# 49997  Soy católica enseñada en escuelas primarias pa...    negativo
# 49998  Voy a tener que estar en desacuerdo con el com...    negativo
# 49999  Nadie espera que las películas de Star Trek se...    negativo
#
# [50000 rows x 2 columns]

# %%
# Pregunta 7: Muestra por pantalla los textos en español de las reseñas negativas
imdb[imdb['sentimiento'] == 'negativo'][['review_es']]
# Out:
#                                                review_es
# 3      Básicamente, hay una familia donde un niño peq...
# 7      Este espectáculo fue una idea increíble, fresc...
# 8      Alentados por los comentarios positivos sobre ...
# 10     Phil El alienígena es una de esas películas pe...
# 11     Vi esta película cuando tenía alrededor de 12 ...
# ...                                                  ...
# 49994  Esta es tu comedia de chatarra típica. Casi no...
# 49996  Mala parcela, mal diálogo, mala actuación, dir...
# 49997  Soy católica enseñada en escuelas primarias pa...
# 49998  Voy a tener que estar en desacuerdo con el com...
# 49999  Nadie espera que las películas de Star Trek se...
#
# [25000 rows x 1 columns]

# %%
# Pregunta 8: Muestra por pantalla el número de reseñas positivas y negativas
imdb['sentimiento'].value_counts()
# Out:
# positivo    25000
# negativo    25000
# Name: sentimiento, dtype: int64

# %%
# Pregunta 9: Crea dos DataFrames distintos para las reseñas en español y en inglés
imdb_es = imdb.loc[:, ['review_es', 'sentimiento']]
imdb_en = imdb.loc[:, ['review_en', 'sentiment']]
imdb_en.head()

# %%
imdb_es.head()

# %%
# Out:
#                                            review_en sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. The filming tec...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
# Pregunta 10: Combina los dos DataFrames anteriores para obtener un DataFrame equivalente al que creaste a partir del dataset al comienzo del cuaderno
# No te preocupes por el orden de la columnas
imdb_entero = pd.concat([imdb_en, imdb_es], axis=1)
imdb_entero.head()
# Out:
#                                            review_es sentimiento  \
# 0  Uno de los otros críticos ha mencionado que de...    positivo
# 1  Una pequeña pequeña producción.La técnica de f...    positivo
# 2  Pensé que esta era una manera maravillosa de p...    positivo
# 3  Básicamente, hay una familia donde un niño peq...    negativo
# 4  El "amor en el tiempo" de Petter Mattei es una...    positivo
#
#                                            review_en sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. The filming tec...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
